# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#https://www.kaggle.com/manchunhui/world-development-indicators
#https://databank.worldbank.org/source/world-development-indicators
#Get data
data = pd.read_csv('./world-development-indicators/Indicators.csv')
data.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
countries = data['CountryName'].unique().tolist()
countries = sorted(countries)
countries
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
# ...

# %%
indicators = data['IndicatorName'].unique().tolist()
indicators = sorted(indicators)

# %%
indicators[:500]
# Out:
# ['2005 PPP conversion factor, GDP (LCU per international $)',
#  '2005 PPP conversion factor, private consumption (LCU per international $)',
#  'ARI treatment (% of children under 5 taken to a health provider)',
#  'Access to electricity (% of population)',
#  'Access to electricity, rural (% of rural population)',
#  'Access to electricity, urban (% of urban population)',
#  'Access to non-solid fuel (% of population)',
#  'Access to non-solid fuel, rural (% of rural population)',
#  'Access to non-solid fuel, urban (% of urban population)',
#  'Adequacy of social insurance programs (% of total welfare of beneficiary households)',
#  'Adequacy of social protection and labor programs (% of total welfare of beneficiary households)',
#  'Adequacy of social safety net programs (% of total welfare of beneficiary households)',
#  'Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)',
#  'Adjusted net enrolment rate, primary, both sexes (%)',
# ...

# %%
indicators[500:1000]
# Out:
# ['Gross domestic income (constant 2005 US$)',
#  'Gross domestic income (constant LCU)',
#  'Gross domestic savings (% of GDP)',
#  'Gross domestic savings (constant LCU)',
#  'Gross domestic savings (current LCU)',
#  'Gross domestic savings (current US$)',
#  'Gross enrolment ratio, pre-primary, both sexes (%)',
#  'Gross enrolment ratio, pre-primary, female (%)',
#  'Gross enrolment ratio, pre-primary, male (%)',
#  'Gross enrolment ratio, primary and secondary, gender parity index (GPI)',
#  'Gross enrolment ratio, primary, both sexes (%)',
#  'Gross enrolment ratio, primary, female (%)',
#  'Gross enrolment ratio, primary, gender parity index (GPI)',
#  'Gross enrolment ratio, primary, male (%)',
#  'Gross enrolment ratio, secondary, both sexes (%)',
#  'Gross enrolment ratio, secondary, female (%)',
#  'Gross enrolment ratio, secondary, gender parity index (GPI)',
#  'Gross enrolment ratio, secondary, male (%)',
#  'Gross enrolment ratio, tertiary, both sexes (%)',
# ...

# %%
indicators[1000:2000]
# Out:
# ['PPG, official creditors (NTR, current US$)',
#  'PPG, official creditors (TDS, current US$)',
#  'PPG, other private creditors (AMT, current US$)',
#  'PPG, other private creditors (DIS, current US$)',
#  'PPG, other private creditors (DOD, current US$)',
#  'PPG, other private creditors (INT, current US$)',
#  'PPG, other private creditors (NFL, current US$)',
#  'PPG, other private creditors (NTR, current US$)',
#  'PPG, other private creditors (TDS, current US$)',
#  'PPG, private creditors (AMT, current US$)',
#  'PPG, private creditors (DIS, current US$)',
#  'PPG, private creditors (DOD, current US$)',
#  'PPG, private creditors (INT, current US$)',
#  'PPG, private creditors (NFL, current US$)',
#  'PPG, private creditors (NTR, current US$)',
#  'PPG, private creditors (TDS, current US$)',
#  'PPP conversion factor, GDP (LCU per international $)',
#  'PPP conversion factor, private consumption (LCU per international $)',
# ...

# %%
#1960-2015
years = data['Year'].unique().tolist()
years = sorted(years)

# %%
#search if any indicator of interest
matching_indicators = [s for s in indicators if "GNI" in s]
matching_indicators
# Out:
# ['Adjusted net savings, excluding particulate emission damage (% of GNI)',
#  'Adjusted net savings, including particulate emission damage (% of GNI)',
#  'Adjusted savings: carbon dioxide damage (% of GNI)',
#  'Adjusted savings: consumption of fixed capital (% of GNI)',
#  'Adjusted savings: education expenditure (% of GNI)',
#  'Adjusted savings: energy depletion (% of GNI)',
#  'Adjusted savings: gross savings (% of GNI)',
#  'Adjusted savings: mineral depletion (% of GNI)',
#  'Adjusted savings: natural resources depletion (% of GNI)',
#  'Adjusted savings: net forest depletion (% of GNI)',
#  'Adjusted savings: net national savings (% of GNI)',
#  'Adjusted savings: particulate emission damage (% of GNI)',
#  'Cost of business start-up procedures (% of GNI per capita)',
#  'External debt stocks (% of GNI)',
#  'GNI (constant 2005 US$)',
#  'GNI (constant LCU)',
#  'GNI (current LCU)',
#  'GNI (current US$)',
#  'GNI growth (annual %)',
#  'GNI per capita (constant 2005 US$)',
# ...

# %%
country_filter = ['United States']

# %%
country_mask = data['CountryName'].str.contains('United States')
indicator_mask = data['IndicatorName'].str.contains('Gross savings \(% of GNI')
data_filter = data[country_mask & indicator_mask]
data_filter.head()
# Out:
#           CountryName CountryCode             IndicatorName  \
# 358055  United States         USA  Gross savings (% of GNI)
# 426045  United States         USA  Gross savings (% of GNI)
# 495842  United States         USA  Gross savings (% of GNI)
# 565259  United States         USA  Gross savings (% of GNI)
# 635341  United States         USA  Gross savings (% of GNI)
#
#             IndicatorCode  Year      Value
# 358055  NY.GNS.ICTR.GN.ZS  1970  21.486018
# 426045  NY.GNS.ICTR.GN.ZS  1971  21.462413
# 495842  NY.GNS.ICTR.GN.ZS  1972  22.028916
# 565259  NY.GNS.ICTR.GN.ZS  1973  23.628127
# 635341  NY.GNS.ICTR.GN.ZS  1974  22.516479

# %%
def draw_plots_country(df, country, title, yaxislabel):
    import matplotlib.pyplot as plt
    import numpy as np

    fig1 = plt.figure(figsize=(10,10))
    ax1 = fig1.add_subplot(111)

    #labels = []
    ax1.plot(df['Year'].values, df['Value'].values,label=country)

    plt.xlabel('Year', fontsize=10)
    plt.ylabel(yaxislabel, fontsize=10)
    plt.title(title, fontsize=15,ha='center')

    #plt.axis([1995, 2013, 0, 20])
    ax1.yaxis.grid(True)
    plt.legend(country, loc='upper right', bbox_to_anchor=(1.0, 1.01), shadow=True, ncol=1)

# %%
draw_plots_country(data_filter,'United States','Gross savings (% of GNI) of USA','Gross savings (% of GNI)')

# %%
country_mask = data['CountryName'].str.contains('United States')
indicator_mask = data['IndicatorName'].str.contains('GNI growth \(annual')
data_filter = data[country_mask & indicator_mask]
data_filter.head()
# Out:
#           CountryName CountryCode          IndicatorName      IndicatorCode  \
# 426004  United States         USA  GNI growth (annual %)  NY.GNP.MKTP.KD.ZG
# 495798  United States         USA  GNI growth (annual %)  NY.GNP.MKTP.KD.ZG
# 565220  United States         USA  GNI growth (annual %)  NY.GNP.MKTP.KD.ZG
# 635300  United States         USA  GNI growth (annual %)  NY.GNP.MKTP.KD.ZG
# 707779  United States         USA  GNI growth (annual %)  NY.GNP.MKTP.KD.ZG
#
#         Year     Value
# 426004  1971  3.353178
# 495798  1972  5.280730
# 565220  1973  5.873473
# 635300  1974 -0.406501
# 707779  1975 -0.425905

# %%
draw_plots_country(data_filter,'United States','GNI growth (annual %) of USA','GNI growth (annual %)')

# %%
indicator_mask = data['IndicatorName'].str.contains('Gross savings \(% of GNI')
data_filter = data[indicator_mask]
data_filter.head()
# Out:
#         CountryName CountryCode             IndicatorName      IndicatorCode  \
# 4288      Australia         AUS  Gross savings (% of GNI)  NY.GNS.ICTR.GN.ZS
# 12441        Israel         ISR  Gross savings (% of GNI)  NY.GNS.ICTR.GN.ZS
# 19400  South Africa         ZAF  Gross savings (% of GNI)  NY.GNS.ICTR.GN.ZS
# 28143     Australia         AUS  Gross savings (% of GNI)  NY.GNS.ICTR.GN.ZS
# 37489        Israel         ISR  Gross savings (% of GNI)  NY.GNS.ICTR.GN.ZS
#
#        Year      Value
# 4288   1960  28.997836
# 12441  1960  30.096712
# 19400  1960  22.344752
# 28143  1961  29.194152
# 37489  1961  30.184147

# %%
data_filter = data_filter[['CountryName','Year','Value']]

# %%
data_filter.head()
# Out:
#         CountryName  Year      Value
# 4288      Australia  1960  28.997836
# 12441        Israel  1960  30.096712
# 19400  South Africa  1960  22.344752
# 28143     Australia  1961  29.194152
# 37489        Israel  1961  30.184147

# %%
indicator_mask = data['IndicatorName'].str.contains('GDP growth \(annual %')
data_filter = data[indicator_mask]
data_filter.head()
data_filter['CountryName'].unique().tolist()
# Out:
# ['East Asia & Pacific (all income levels)',
#  'East Asia & Pacific (developing only)',
#  'Euro area',
#  'Europe & Central Asia (all income levels)',
#  'European Union',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income: OECD',
#  'Latin America & Caribbean (all income levels)',
#  'Latin America & Caribbean (developing only)',
#  'Low & middle income',
#  'Lower middle income',
#  'Middle income',
#  'North America',
#  'OECD members',
#  'South Asia',
#  'Sub-Saharan Africa (all income levels)',
#  'Sub-Saharan Africa (developing only)',
#  'Upper middle income',
#  'World',
#  'Algeria',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bahamas, The',
#  'Bangladesh',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bolivia',
#  'Botswana',
#  'Brazil',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
# ...

# %%
#East Asia & Pacific
#Europe & Central Asia (all income levels)
#'Latin America & Caribbean (all income levels)

# %%
indicator_mask = data['IndicatorName'].str.contains('corruption')
data_filter = data[indicator_mask]
data_filter.head()
#data_filter['IndicatorName'].unique().tolist()
# Out:
#                                        CountryName CountryCode  \
# 3942732                                 Arab World         ARB
# 3943263                     Caribbean small states         CSS
# 3944452    East Asia & Pacific (all income levels)         EAS
# 3945071      East Asia & Pacific (developing only)         EAP
# 3946473  Europe & Central Asia (all income levels)         ECS
#
#                                              IndicatorName   IndicatorCode  \
# 3942732  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ
# 3943263  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ
# 3944452  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ
# 3945071  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ
# 3946473  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ
#
#          Year     Value
# 3942732  2005  2.500000
# 3943263  2005  3.900000
# 3944452  2005  2.863636
# 3945071  2005  2.863636
# ...

# %%
data_filter['CountryName'].unique().tolist()
# Out:
# ['Arab World',
#  'Caribbean small states',
#  'East Asia & Pacific (all income levels)',
#  'East Asia & Pacific (developing only)',
#  'Europe & Central Asia (all income levels)',
#  'Europe & Central Asia (developing only)',
#  'Fragile and conflict affected situations',
#  'Heavily indebted poor countries (HIPC)',
#  'Latin America & Caribbean (all income levels)',
#  'Latin America & Caribbean (developing only)',
#  'Least developed countries: UN classification',
#  'Low & middle income',
#  'Low income',
#  'Lower middle income',
#  'Middle East & North Africa (all income levels)',
#  'Middle East & North Africa (developing only)',
#  'Middle income',
#  'Other small states',
#  'Pacific island small states',
#  'Small states',
#  'South Asia',
#  'Sub-Saharan Africa (all income levels)',
#  'Sub-Saharan Africa (developing only)',
#  'Upper middle income',
#  'World',
#  'Albania',
#  'Angola',
#  'Armenia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Benin',
#  'Bhutan',
# ...

# %%
#search if any indicator of interest
matching_countries = [s for s in countries if "all income levels" in s]
matching_countries
# Out:
# ['East Asia & Pacific (all income levels)',
#  'Europe & Central Asia (all income levels)',
#  'Latin America & Caribbean (all income levels)',
#  'Middle East & North Africa (all income levels)',
#  'Sub-Saharan Africa (all income levels)']

# %%
corruption_data = data_filter[['CountryName','Year','Value']]
corruption_data.head()
# Out:
#                                        CountryName  Year     Value
# 3942732                                 Arab World  2005  2.500000
# 3943263                     Caribbean small states  2005  3.900000
# 3944452    East Asia & Pacific (all income levels)  2005  2.863636
# 3945071      East Asia & Pacific (developing only)  2005  2.863636
# 3946473  Europe & Central Asia (all income levels)  2005  2.650000

# %%
countries_m = corruption_data['CountryName'].unique().tolist()
years_m = corruption_data['Year'].unique().tolist()

# %%
mean_value = corruption_data.groupby(['CountryName','Year']).sum()
mean_value.tail()
# Out:
#                   Value
# CountryName Year
# Zimbabwe    2010    1.5
#             2011    1.5
#             2012    1.5
#             2013    1.5
#             2014    1.5

# %%
#countries_m = mean_value['CountryName'].unique().tolist()
mean_value = mean_value.reset_index()
mean_value.head()
# Out:
#    CountryName  Year  Value
# 0  Afghanistan  2006    2.5
# 1  Afghanistan  2007    2.0
# 2  Afghanistan  2008    2.0
# 3  Afghanistan  2009    2.0
# 4  Afghanistan  2010    2.0

# %%
mean_value.isnull().values.any()
# Out:
# False

# %%
lm = mean_value['Value'].unique().tolist()
sorted(lm)
# Out:
# [1.0,
#  1.5,
#  2.0,
#  2.2,
#  2.25,
#  2.3,
#  2.4,
#  2.43181818181818,
#  2.4583333333333304,
#  2.4791666666666696,
#  2.5,
#  2.51724137931034,
#  2.525,
#  2.53448275862069,
#  2.55357142857143,
#  2.55555555555556,
#  2.5576923076923097,
#  2.5625,
#  2.56896551724138,
#  2.57142857142857,
#  2.59259259259259,
#  2.6,
#  2.61111111111111,
#  2.625,
#  2.6296296296296298,
#  2.65,
#  2.6578947368421098,
#  2.6666666666666696,
#  2.6710526315789505,
#  2.67307692307692,
#  2.68478260869565,
#  2.69736842105263,
#  2.6976744186046497,
#  2.7,
#  2.70512820512821,
#  2.7093023255814,
#  2.71052631578947,
#  2.71621621621622,
#  2.72368421052632,
#  2.72619047619048,
#  2.7333333333333303,
#  2.73684210526316,
#  2.7432432432432403,
#  2.7441860465116297,
#  2.75,
#  2.75675675675676,
#  2.77027027027027,
#  2.77380952380952,
#  2.77631578947368,
#  2.77777777777778,
#  2.7875,
#  2.7972972972973,
#  2.85064935064935,
#  2.86363636363636,
#  2.86666666666667,
# ...

# %%
mean_value[mean_value['CountryName'].str.contains('Middle East & North Africa')].head()
# Out:
#                                         CountryName  Year  Value
# 594  Middle East & North Africa (all income levels)  2005   2.75
# 595  Middle East & North Africa (all income levels)  2006   2.75
# 596  Middle East & North Africa (all income levels)  2007   2.75
# 597  Middle East & North Africa (all income levels)  2008   2.75
# 598  Middle East & North Africa (all income levels)  2009   2.75

# %%
dfObj = pd.DataFrame(columns=['CountryName','MeanValue'])
i  = 0
for c in countries_m:
    c_list = []
    c_list.append(c)
    #str contains does not work for cases where special characters like brackets
    c_mask = mean_value['CountryName'].isin(c_list)
    df1 = mean_value[c_mask]    
    l = df1['Value'].unique().tolist()
    meanValue = pd.Series(l).mean()    
    dfObj.loc[i] = np.array([c,meanValue])        
    i += 1
    
    
dfObj.head()
# Out:
#                                  CountryName           MeanValue
# 0                                 Arab World                 2.4
# 1                     Caribbean small states  3.8499999999999996
# 2    East Asia & Pacific (all income levels)    3.01828692141192
# 3      East Asia & Pacific (developing only)    3.01828692141192
# 4  Europe & Central Asia (all income levels)   2.711284722222222

# %%
df_sorted = dfObj.sort_values('MeanValue', ascending=False)

# %%
df_sorted.head(50)
df_sorted[df_sorted['CountryName'].str.contains('Myanmar')]
# Out:
#     CountryName MeanValue
# 109     Myanmar      2.75

# %%
def draw_multiline_plots_countries(maindf, title, yaxislabel):
    import matplotlib.pyplot as plt
    import numpy as np

    fig1 = plt.figure(figsize=(10,10))
    ax1 = fig1.add_subplot(111)

    labels = []
    for c in countries_m:
        c_list = []
        c_list.append(c)
        #str contains does not work for cases where special characters like brackets
        c_mask = mean_value['CountryName'].isin(c_list)
        df = maindf[c_mask]
        labels.append(c)
        ax1.plot(df['CountryName'].values, df['MeanValue'].values,label=c)


    plt.xlabel('CountryName', fontsize=10)
    plt.ylabel(yaxislabel, fontsize=10)
    plt.title(title, fontsize=15,ha='center')

    #plt.axis([1995, 2013, 0, 20])
    ax1.yaxis.grid(True)
    plt.legend(labels, loc='upper right', bbox_to_anchor=(1.0, 1.01), shadow=True, ncol=1)

# %%
country_mask = data['CountryName'].str.contains('Afghanistan')
ind_mask = data['IndicatorName'].str.contains('GDP Growth')
df = data[ ind_mask]
df.head()
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, IndicatorName, IndicatorCode, Year, Value]
# Index: []

# %%
countries = data['CountryName'].unique().tolist()
indicators = data['IndicatorName'].unique().tolist()

# %%
# Picks years of choice
yearsFilter = [2010, 2011, 2012, 2013, 2014]

# %%
#world largest https://www.focus-economics.com/blog/the-largest-economies-in-the-world
world_largest_eco = ['United States','China', 'Japan', 'Germany', 'United Kingdom','India','France', 'Italy','Brazil']

# %%
filteredData1 = []
filteredData2 = []

# %%
'''
Plot: 
countryFilter:    pick two countries, 
indicatorsFilter: pick an indicator, 
yearsFilter: plot for years in yearsFilter
'''
import random
# problem - not all countries have all indicators so if you go to visualize, it'll have missing data.
# randomly picking two indicators and countries, do these countries have valid data over those years.
# brings up the discussion of missing data/ missing fields
# until we find full data

while(len(filteredData1) < len(yearsFilter)-1):
    # pick new indicator
    indicatorsFilter = random.sample(indicators, 1)
    countryFilter    = world_largest_eco#random.sample(countries, 2)
    # how many rows are there that have this country name, this indicator, and this year.  Mesh gives bool vector
    filterMesh = (data['CountryName'] == countryFilter[0]) & (data['IndicatorName'].isin(indicatorsFilter)) & (data['Year'].isin(yearsFilter))
    # which rows have this condition to be true?
    filteredData1 = data.loc[filterMesh]
    filteredData1 = filteredData1[['CountryName','IndicatorName','Year','Value']]

    # need to print this only when our while condition is true
    if(len(filteredData1) < len(yearsFilter)-1):
        print('Skipping ... %s since very few rows (%d) found' % (indicatorsFilter, len(filteredData1)))

# %%
indicatorsFilter
# Out:
# ['GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)']

# %%
#world largest https://www.focus-economics.com/blog/the-largest-economies-in-the-world
world_largest_eco = ['United States','China', 'Japan', 'Germany', 'United Kingdom','India','France', 'Italy','Brazil']

# %%
country_mask = data['CountryName'].isin(world_largest_eco)
ind_mask = data['IndicatorName'].str.contains('Gross savings \(% of GDP')
df_gs = data[country_mask & ind_mask]
#df_gs.shape
df_gs.head(10)
# Out:
#            CountryName CountryCode             IndicatorName   IndicatorCode  \
# 331114           Italy         ITA  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 357761  United Kingdom         GBR  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 358054   United States         USA  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 389452         Germany         DEU  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 396771           Italy         ITA  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 425720  United Kingdom         GBR  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 426044   United States         USA  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 458424         Germany         DEU  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 465769           Italy         ITA  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
# 495511  United Kingdom         GBR  Gross savings (% of GDP)  NY.GNS.ICTR.ZS
#
#         Year      Value
# 331114  1970  26.922909
# 357761  1970  24.653522
# 358054  1970  21.506947
# ...

# %%
gs_indicator_name = df_gs['IndicatorName'].iloc[0]
del df_gs['CountryCode']
del df_gs['IndicatorName']
del df_gs['IndicatorCode']
df_gs.head(10)
# Out:
#            CountryName  Year      Value
# 331114           Italy  1970  26.922909
# 357761  United Kingdom  1970  24.653522
# 358054   United States  1970  21.506947
# 389452         Germany  1971  29.684240
# 396771           Italy  1971  25.344699
# 425720  United Kingdom  1971  24.206193
# 426044   United States  1971  21.427696
# 458424         Germany  1972  28.389406
# 465769           Italy  1972  24.640184
# 495511  United Kingdom  1972  22.057520

# %%
country_mask = data['CountryName'].isin(world_largest_eco)
ind_mask = data['IndicatorName'].str.contains('GDP growth')
df_gdpgrowth = data[country_mask & ind_mask]
df_gdpgrowth.shape
# Out:
# (476, 6)

# %%
gdp_growth_indicator_name = df_gdpgrowth['IndicatorName'].iloc[0]
del df_gdpgrowth['CountryCode']
del df_gdpgrowth['IndicatorName']
del df_gdpgrowth['IndicatorCode']
df_gdpgrowth.head(10)
# Out:
#           CountryName  Year      Value
# 29762          Brazil  1961  10.275912
# 31483           China  1961 -27.300000
# 34285          France  1961   5.506272
# 36554           India  1961   3.722743
# 37641           Italy  1961   8.207246
# 37964           Japan  1961  12.043536
# 48592  United Kingdom  1961   2.573570
# 48758   United States  1961   2.300000
# 56803          Brazil  1962   5.216059
# 58683           China  1962  -5.600000

# %%
#Ease of doing business index
#GDP growth (annual %)
def draw_multiline_plots_countries(maindf, title, yaxislabel):
    import matplotlib.pyplot as plt
    import numpy as np

    fig1 = plt.figure(figsize=(20,20))
    ax1 = fig1.add_subplot(111)
    
    #print(maindf['region'].iloc[0])
    #this is assuming that region has been assigned.
    maindf = maindf.dropna()    
    countries = maindf['CountryName'].unique().tolist()    
    labels = []
    for c in countries:
        c_list = []
        c_list.append(c)
        c_mask = maindf['CountryName'].isin(c_list)
        df = maindf[c_mask]
        labels.append(c)
        ax1.plot(df['Year'].values, df['Value'].values,label=c)
    
    plt.xlabel('Year', fontsize=10)
    plt.ylabel(yaxislabel, fontsize=10)
    plt.title(title, fontsize=15,ha='center')

    #plt.axis([1995, 2013, 0, 20])
    ax1.yaxis.grid(True)
    plt.legend(labels, loc='upper right', bbox_to_anchor=(1.0, 1.01), shadow=True, ncol=1)

# %%
draw_multiline_plots_countries(df_gdpgrowth,'','')

# %%
draw_multiline_plots_countries(df_gs,'','')

# %%
#GDP per capita (constant 2005 US$)
country_list_ha = ['United States']
indicator_list = ['Health expenditure, private \(% of','Health expenditure, public (% of','Health expenditure, total (% of ']

year_mask =  data['Year'].isin([2013])
country_mask = data['CountryName'].isin(country_list_ha)
ind1_mask = data['IndicatorName'].str.contains('Health expenditure, public \(% of GDP')
ind2_mask = data['IndicatorName'].str.contains('Health expenditure, private \(% of GDP')
ind3_mask = data['IndicatorName'].str.contains('Health expenditure, total \(% of GDP')

df_healthcare = data[country_mask & year_mask & (ind1_mask | ind2_mask | ind3_mask)]
#df_gs.shape
df_healthcare.head(10)
# Out:
#            CountryName CountryCode                           IndicatorName  \
# 5527528  United States         USA  Health expenditure, private (% of GDP)
# 5527529  United States         USA   Health expenditure, public (% of GDP)
# 5527532  United States         USA    Health expenditure, total (% of GDP)
#
#           IndicatorCode  Year      Value
# 5527528  SH.XPD.PRIV.ZS  2013   9.046722
# 5527529  SH.XPD.PUBL.ZS  2013   8.050918
# 5527532  SH.XPD.TOTL.ZS  2013  17.097640

# %%
#GDP per capita (constant 2005 US$)
#United States, Switzerland, Luxembourg,Norway,Germany, Sweden , Netherlands,Denmark,France,Austria,Japan
#Ireland, Belgium, Iceland, Canada,United Kingdom,Australia,Finland
country_list_ha = ['Canada']
indicator_list = ['Health expenditure, private \(% of','Health expenditure, public (% of','Health expenditure, total (% of ']

year_mask =  data['Year'].isin([2013])
country_mask = data['CountryName'].isin(country_list_ha)
ind1_mask = data['IndicatorName'].str.contains('Health expenditure, public \(% of GDP')
ind2_mask = data['IndicatorName'].str.contains('Health expenditure, private \(% of GDP')
ind3_mask = data['IndicatorName'].str.contains('Health expenditure, total \(% of GDP')

df_healthcare = data[country_mask & year_mask & (ind1_mask | ind2_mask | ind3_mask)]
#df_gs.shape
df_healthcare.head(10)
# Out:
#         CountryName CountryCode                           IndicatorName  \
# 5420146      Canada         CAN  Health expenditure, private (% of GDP)
# 5420147      Canada         CAN   Health expenditure, public (% of GDP)
# 5420150      Canada         CAN    Health expenditure, total (% of GDP)
#
#           IndicatorCode  Year      Value
# 5420146  SH.XPD.PRIV.ZS  2013   3.280067
# 5420147  SH.XPD.PUBL.ZS  2013   7.580629
# 5420150  SH.XPD.TOTL.ZS  2013  10.860696

# %%
check_years = np.arange(2000,2014,1)
len(check_years)
# Out:
# 14

# %%
#check following years
check_countries = ['United States', 'Switzerland', 'Luxembourg','Norway','Germany', 'Sweden' ,'Netherlands' ,'Denmark',
                   'France','Austria','Japan','Ireland', 'Belgium', 'Iceland', 'Canada','United Kingdom','Australia','Finland']
check_years = np.arange(1980,2014,1)
#[2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
valid_years = []

for c in check_countries:
    valid_years = []
    for y in check_years:
        #print(y)
        country_list_ha = [c]
        indicator_list = ['Health expenditure, private \(% of','Health expenditure, public (% of','Health expenditure, total (% of ']

        year_mask =  data['Year'].isin([y])
        country_mask = data['CountryName'].isin(country_list_ha)
        ind1_mask = data['IndicatorName'].str.contains('Health expenditure, public \(% of GDP')
        ind2_mask = data['IndicatorName'].str.contains('Health expenditure, private \(% of GDP')
        ind3_mask = data['IndicatorName'].str.contains('Health expenditure, total \(% of GDP')

        df_healthcare = data[country_mask & year_mask & (ind1_mask | ind2_mask | ind3_mask)]
        if (df_healthcare.shape[0] == 3):
            valid_years.append(y)
        
    if (len(valid_years) == len(check_years)):
        print(valid_years)
    else:
        print(valid_years)
        print('Invalid years:' + c + " len:"+ str(len(valid_years)))
# Out:
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:United States len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Switzerland len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Luxembourg len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Norway len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Germany len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Sweden len:19
# ...

# %% [markdown]
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:United States len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Switzerland len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Luxembourg len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Norway len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Germany len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Sweden len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Netherlands len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Denmark len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:France len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Austria len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Japan len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Ireland len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Belgium len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Iceland len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Canada len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:United Kingdom len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Australia len:19
# [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Invalid years:Finland len:19

# %%
#https://www.investopedia.com/ask/answers/020915/what-country-spends-most-healthcare.asp
#https://www.modernhealthcare.com/article/20190220/NEWS/190229989/healthcare-spending-will-hit-19-4-of-gdp-in-the-next-decade-cms-projects
#https://www.healthsystemtracker.org/chart-collection/health-spending-u-s-compare-countries/#item-u-s-increased-public-private-sector-spending-faster-rate-similar-countries

df_healthcare = df_healthcare.sort_values(by=['Value'], ascending=False)
df_healthcare.head(30)
# Out:
#                    CountryName CountryCode  \
# 5524072                 Tuvalu         TUV
# 5527532          United States         USA
# 5476123       Marshall Islands         MHL
# 5391453          North America         NAC
# 5486051            Netherlands         NLD
# 5384861      High income: OECD         OEC
# 5478932  Micronesia, Fed. Sts.         FSM
# 5391955           OECD members         OED
# 5383780            High income         HIC
# 5504991           Sierra Leone         SLE
# 5479510                Moldova         MDA
# 5440401                 France         FRA
# 5467298                Lesotho         LSO
# 5515866            Switzerland         CHE
# 5443601                Germany         DEU
# 5408069                Belgium         BEL
# 5500064                 Rwanda         RWA
# 5403480                Austria         AUT
# 5420150                 Canada         CAN
# 5474305               Maldives         MDV
# 5431171                Denmark         DNK
# ...

# %%
def group_stacked_bar_test():
    # Data and imports
    import pandas as pd
    import matplotlib.pyplot as plt
    import numpy as np
    from matplotlib.ticker import MaxNLocator
    import matplotlib.gridspec as gridspec
    import matplotlib

    matplotlib.style.use('ggplot')

    np.random.seed(0)

    df = pd.DataFrame(np.asarray(1+5*np.random.random((10,4)), dtype=int),columns=["Cluster", "Bar", "Bar_part", "Count"])
    df = df.groupby(["Cluster", "Bar", "Bar_part"])["Count"].sum().unstack(fill_value=0)
    display(df)

    # plotting

    clusters = df.index.levels[0]
    inter_graph = 0
    maxi = np.max(np.sum(df, axis=1))
    total_width = len(df)+inter_graph*(len(clusters)-1)

    fig = plt.figure(figsize=(total_width,10))
    gridspec.GridSpec(1, total_width)
    axes=[]

    ax_position = 0
    for cluster in clusters:
        subset = df.loc[cluster]
        ax = subset.plot(kind="bar", stacked=True, width=0.8, ax=plt.subplot2grid((1,total_width), (0,ax_position), colspan=len(subset.index)))
        axes.append(ax)
        ax.set_title(cluster)
        ax.set_xlabel("")
        ax.set_ylim(0,maxi+1)
        ax.yaxis.set_major_locator(MaxNLocator(integer=True))
        ax_position += len(subset.index)+inter_graph

    for i in range(1,len(clusters)):
        axes[i].set_yticklabels("")
        axes[i-1].legend().set_visible(False)
    axes[0].set_ylabel("y_label")

    fig.suptitle('Big Title', fontsize="x-large")
    legend = axes[-1].legend(loc='upper right', fontsize=16, framealpha=1).get_frame()
    legend.set_linewidth(3)
    legend.set_edgecolor("black")

    plt.show()

# %%
#https://stackoverflow.com/questions/22787209/how-to-have-clusters-of-stacked-bars-with-python-pandas
group_stacked_bar_test()
# Out:
# Bar_part     1  2  3  4  5
# Cluster Bar
# 1       4    5  0  0  0  0
#         5    0  0  0  5  0
# 3       3    4  4  0  0  0
#         4    0  0  5  3  0
#         5    1  0  0  0  0
# 4       4    0  0  0  0  4
# 5       2    0  0  0  3  0
#         4    0  0  4  0  0

# %%
#https://stackoverflow.com/questions/22787209/how-to-have-clusters-of-stacked-bars-with-python-pandas
import pandas as pd
import matplotlib.cm as cm
import numpy as np
import matplotlib.pyplot as plt

def plot_clustered_stacked(dfall, labels=None, title="multiple stacked bar plot",  H="/", **kwargs):
    """Given a list of dataframes, with identical columns and index, create a clustered stacked bar plot. 
    labels is a list of the names of the dataframe, used for the legend
    title is a string for the title of the plot
    H is the hatch used for identification of the different dataframe"""
    n_df = len(dfall)
    n_col = len(dfall[0].columns) 
    n_ind = len(dfall[0].index)
    axe = plt.subplot(111)

    for df in dfall : # for each data frame
        axe = df.plot(kind="bar",
                      linewidth=0,
                      stacked=True,
                      ax=axe,
                      legend=False,
                      grid=False,
                      **kwargs)  # make bar plots

    h,l = axe.get_legend_handles_labels() # get the handles we want to modify
    for i in range(0, n_df * n_col, n_col): # len(h) = n_col * n_df
        for j, pa in enumerate(h[i:i+n_col]):
            for rect in pa.patches: # for each index
                rect.set_x(rect.get_x() + 1 / float(n_df + 1) * i / float(n_col))
                rect.set_hatch(H * int(i / n_col)) #edited part     
                rect.set_width(1 / float(n_df + 1))

                
                            
    axe.set_xticks((np.arange(0, 2 * n_ind, 2) + 1 / float(n_df + 1)) / 2.)
    axe.set_xticklabels(df.index, rotation = 0)
    axe.set_title(title)

    # Add invisible data to add another legend
    n=[]        
    for i in range(n_df):
        n.append(axe.bar(0, 0, color="gray", hatch=H * i))

    l1 = axe.legend(h[:n_col], l[:n_col], loc=[1.01, 0.5])
    if labels is not None:
        l2 = plt.legend(n, labels, loc=[1.01, 0.1]) 
    axe.add_artist(l1)
    return axe

# create fake dataframes
df1 = pd.DataFrame(np.random.rand(4, 5),##private and public values
                   index=["A", "B", "C", "D"],#year
                   columns=["I", "J", "K", "L", "M"])#private and public header
df2 = pd.DataFrame(np.random.rand(4, 5),
                   index=["A", "B", "C", "D"],#year
                   columns=["I", "J", "K", "L", "M"])#private and public header
df3 = pd.DataFrame(np.random.rand(4, 5),
                   index=["A", "B", "C", "D"], #year
                   columns=["I", "J", "K", "L", "M"])#private and public header

# Then, just call :
plot_clustered_stacked([df1, df2, df3],["df1", "df2", "df3"])

# %%
y_list = [2000, 2012]
c_list = ['United States']
year_mask =  data['Year'].isin(y_list)
country_mask = data['CountryName'].isin(c_list)
ind1_mask = data['IndicatorName'].str.contains('Health expenditure, public \(% of GDP')
ind2_mask = data['IndicatorName'].str.contains('Health expenditure, private \(% of GDP')
#ind3_mask = data['IndicatorName'].str.contains('Health expenditure, total \(% of GDP')

us_h_public = data[year_mask & country_mask & ind1_mask ]
#us_h.shape
us_h_public.head()
us_h_private = data[year_mask & country_mask & ind2_mask ]

# %%
us_h_public = us_h_public[['Year','Value']]
us_h_private = us_h_private[['Year','Value']]

# %%
us_h_public.head()
# Out:
#          Year     Value
# 3319115  2000  5.658535
# 5370104  2012  8.005012

# %%
us_h_public=us_h_public.rename(columns = {'Value':'public'})
us_h_private=us_h_private.rename(columns = {'Value':'private'})


us_h = pd.merge(us_h_public, us_h_private, how='inner')
us_h = us_h.set_index('Year')
us_h.head()
# Out:
#         public   private
# Year
# 2000  5.658535  7.485655
# 2012  8.005012  9.042650

# %%
y_list = [2000, 2012]
c_list = ['Switzerland']
year_mask =  data['Year'].isin(y_list)
country_mask = data['CountryName'].isin(c_list)
ind1_mask = data['IndicatorName'].str.contains('Health expenditure, public \(% of GDP')
ind2_mask = data['IndicatorName'].str.contains('Health expenditure, private \(% of GDP')
#ind3_mask = data['IndicatorName'].str.contains('Health expenditure, total \(% of GDP')

sz_h_public = data[year_mask & country_mask & ind1_mask ]
sz_h_private = data[year_mask & country_mask & ind2_mask ]

sz_h_public = sz_h_public[['Year','Value']]
sz_h_private = sz_h_private[['Year','Value']]

sz_h_public=sz_h_public.rename(columns = {'Value':'public'})
sz_h_private=sz_h_private.rename(columns = {'Value':'private'})


sz_h = pd.merge(sz_h_public, sz_h_private, how='inner')
sz_h = sz_h.set_index('Year')
sz_h.head()
# Out:
#         public   private
# Year
# 2000  5.492176  4.415874
# 2012  7.522825  3.907573

# %%
year_h = [str(x) for x in y_list]#pd.Series([str(x) for x in y_list])
year_h
# Out:
# ['2000', '2012']

# %%
#https://stackoverflow.com/questions/22787209/how-to-have-clusters-of-stacked-bars-with-python-pandas
def plot_clustered_stacked_mod(dfall, labels=None, title="multiple stacked bar plot",  H="/", **kwargs):
    """Given a list of dataframes, with identical columns and index, create a clustered stacked bar plot. 
    labels is a list of the names of the dataframe, used for the legend
    title is a string for the title of the plot
    H is the hatch used for identification of the different dataframe"""
    import pandas as pd
    import matplotlib.cm as cm
    import numpy as np
    import matplotlib.pyplot as plt
    from functools import reduce

    n_df = len(dfall)
    n_col = len(dfall[0].columns) 
    n_ind = len(dfall[0].index)
    axe = plt.subplot(111)
    x_major_index = []
   
    for df in dfall : # for each data frame
        axe = df.plot(kind="bar",
                      linewidth=0,
                      stacked=True,
                      ax=axe,
                      legend=False,
                      grid=False,
                      **kwargs)  # make bar plots
        x_major_index = df.index #years

    h,l = axe.get_legend_handles_labels() # get the handles we want to modify
    for i in range(0, n_df * n_col, n_col): # len(h) = n_col * n_df
        for j, pa in enumerate(h[i:i+n_col]):
            for rect in pa.patches: # for each index
                rect.set_x(rect.get_x() + 1 / float(n_df + 1) * i / float(n_col))
                #rect.set_hatch(H * int(i / n_col)) #edited part     
                rect.set_width(1 / float(n_df + 1))

                
    label_x, label_mode = [], []

    startPoint = -0.1
    loop = 0
    
    #this is for the countries : minor lables
    for xindex in x_major_index:
        print(xindex)
        for rect, idx in zip(axe.patches, labels):        
            label_mode.append(idx[0]) 
            print(rect, idx[0], rect.xy[0], loop , startPoint)
            label_x.append(startPoint + (loop * 0.3))
            loop += 1
        loop += 1.5
    
    axe.set_xticklabels(x_major_index)
    axe.set_xticks(label_x, minor=True)
    axe.set_xticklabels(label_mode, minor=True)
    axe.tick_params(axis='x', which='minor', length=10)
    axe.tick_params(axis='x', which='major', length=10, width=0)
    axe.xaxis.remove_overlapping_locs = False
    #axe.set_xticks((np.arange(0, 2 * n_ind, 2) + 1 / float(n_df + 1)) / 2.)
    #axe.set_xticklabels(df.index, rotation = 90)
    axe.set_title(title)

   
   
    n = []
    l1 = axe.legend(h[:n_col], l[:n_col], loc=[1.01, 0.5])
    if labels is not None:
        l2 = plt.legend(n, labels, loc=[1.01, 0.1]) 
    axe.add_artist(l1)
    return axe

# %%
plot_clustered_stacked_mod([us_h, sz_h],["us_h","sz_h"])
# Out:
# 2000
# Rectangle(xy=(-0.25, 0), width=0.333333, height=5.65854, angle=0) u -0.25 0 -0.1
# Rectangle(xy=(0.75, 0), width=0.333333, height=8.00501, angle=0) s 0.75 1 -0.1
# 2012
# Rectangle(xy=(-0.25, 0), width=0.333333, height=5.65854, angle=0) u -0.25 3.5 -0.1
# Rectangle(xy=(0.75, 0), width=0.333333, height=8.00501, angle=0) s 0.75 4.5 -0.1

# %%
#https://stackoverflow.com/questions/43545879/bar-chart-with-multiple-labels
from functools import reduce
df = pd.DataFrame(np.random.rand(6, 4),
                 index=['one', 'two', 'three', 'four', 'five', 'six'],
                 columns=pd.Index(['A', 'B', 'C', 'D'],
                 name='Genus')).round(2)

ax = df.plot(kind='bar',figsize=(10,4), rot = 0)

# "Activate" minor ticks
ax.minorticks_on()

# Get location of the center of each rectangle
rects_locs = list(map(lambda x: x.get_x() +x.get_width()/2., ax.patches))
# Set minor ticks there
ax.set_xticks(rects_locs, minor = True)


# Labels for the rectangles
new_ticks = reduce(lambda x, y: x + y, map(lambda x: [x] * df.shape[0], df.columns.tolist()))
# Set the labels
from matplotlib import ticker
ax.xaxis.set_minor_formatter(ticker.FixedFormatter(new_ticks))  #add the custom ticks

# Move the category label further from x-axis
ax.tick_params(axis='x', which='major', pad=15)

# Remove minor ticks where not necessary
ax.tick_params(axis='x',which='both', top='off')
ax.tick_params(axis='y',which='both', left='off', right = 'off')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(
    {
        0: [84, 41],
        1: [50, 40],
        2: [18.5, 3.5],
        3: [65.5, 124],
        4: [0.5, 0]
    },
    index = ['A', 'B']
)

ax = df.plot.bar(
    rot=0,
    legend=False,
    color=['gray', 'red', 'green', 'lightblue', 'darkblue',],
)

labels = df.unstack().index
label_x, label_mode = [], []

for rect, idx in zip(ax.patches, labels):
    print(rect, idx)
    label_mode.append(idx[0])
    label_x.append(rect.xy[0] + (rect.get_width() * 0.5))

ax.set_xticklabels(['A', 'B'])
ax.set_xticks(label_x, minor=True)
ax.set_xticklabels(label_mode, minor=True)
ax.tick_params(axis='x', which='minor', length=0)
ax.tick_params(axis='x', which='major', length=10, width=0)
ax.xaxis.remove_overlapping_locs = False
# Out:
# Rectangle(xy=(-0.25, 0), width=0.1, height=84, angle=0) (0, 'A')
# Rectangle(xy=(0.75, 0), width=0.1, height=41, angle=0) (0, 'B')
# Rectangle(xy=(-0.15, 0), width=0.1, height=50, angle=0) (1, 'A')
# Rectangle(xy=(0.85, 0), width=0.1, height=40, angle=0) (1, 'B')
# Rectangle(xy=(-0.05, 0), width=0.1, height=18.5, angle=0) (2, 'A')
# Rectangle(xy=(0.95, 0), width=0.1, height=3.5, angle=0) (2, 'B')
# Rectangle(xy=(0.05, 0), width=0.1, height=65.5, angle=0) (3, 'A')
# Rectangle(xy=(1.05, 0), width=0.1, height=124, angle=0) (3, 'B')
# Rectangle(xy=(0.15, 0), width=0.1, height=0.5, angle=0) (4, 'A')
# Rectangle(xy=(1.15, 0), width=0.1, height=0, angle=0) (4, 'B')

# %%
df = pd.DataFrame(
    {
        0: [84, 41],
        1: [50, 40],
        2: [18.5, 3.5],
        3: [65.5, 124],
        4: [0.5, 0]
    },
    index = ['A', 'B']
)
df.head()
# Out:
#     0   1     2      3    4
# A  84  50  18.5   65.5  0.5
# B  41  40   3.5  124.0  0.0

# %%
df.index
# Out:
# Index(['A', 'B'], dtype='object')

# %%
#https://stackoverflow.com/questions/22787209/how-to-have-clusters-of-stacked-bars-with-python-pandas
def plot_clustered_stacked_mod2(dfall, labels=None, title="multiple stacked bar plot",  H="/", **kwargs):  
    import pandas as pd
    import matplotlib.cm as cm
    import numpy as np
    import matplotlib.pyplot as plt
    from functools import reduce

    n_df = len(dfall)
    n_col = len(dfall[0].columns) 
    n_ind = len(dfall[0].index)
    axe = plt.subplot(111)
    x_major_index = []
   
    for df in dfall : # for each data frame
        axe = df.plot(kind="bar",
                      linewidth=0,
                      stacked=True,
                      ax=axe,
                      legend=False,
                      grid=False,
                      color=['lightblue', 'darkblue'],
                      **kwargs)  # make bar plots
        x_major_index = df.index #years

    h,l = axe.get_legend_handles_labels() # get the handles we want to modify
    for i in range(0, n_df * n_col, n_col): # len(h) = n_col * n_df
        for j, pa in enumerate(h[i:i+n_col]):
            for rect in pa.patches: # for each index
                rect.set_x(rect.get_x() + 1 / float(n_df + 1) * i / float(n_col))
                #rect.set_hatch(H * int(i / n_col)) #edited part     
                rect.set_width(1 / float(n_df + 1))

                
    label_x, label_mode = [], []

    startPoint = -0.1
    loop = 0
    
    #this is for the countries : minor lables
    for xindex in x_major_index:
        print(xindex)
        for rect, idx in zip(axe.patches, labels):        
            label_mode.append(idx) 
            print(rect, idx[0], rect.xy[0], loop , startPoint)
            label_x.append(startPoint + (loop * 0.3))
            loop += 1
        loop += 1.5
    
    
    axe.set_xticklabels(x_major_index, rotation = 0)
    axe.set_xticks(label_x, minor=True)
    axe.set_xticklabels(label_mode, minor=True, rotation = 45)
    axe.tick_params(axis='x', which='minor', length=10, )
    
    #hide major tick:length = 0
    axe.tick_params(axis='x', which='major', length=0, pad=80)
    axe.xaxis.remove_overlapping_locs = False
    #axe.set_xticks((np.arange(0, 2 * n_ind, 2) + 1 / float(n_df + 1)) / 2.)
    #axe.set_xticklabels(df.index, rotation = 90)
    axe.set_title(title)

   
   
    n = []
    l1 = axe.legend(h[:n_col], l[:n_col], loc=[1.01, 0.5])
    if labels is not None:
        l2 = plt.legend(n, labels, loc=[1.01, 0.1]) 
    axe.add_artist(l1)
    return axe

# %%
plot_clustered_stacked_mod2([us_h, sz_h],["United States","Switzerland"])
# Out:
# 2000
# Rectangle(xy=(-0.25, 0), width=0.333333, height=5.65854, angle=0) U -0.25 0 -0.1
# Rectangle(xy=(0.75, 0), width=0.333333, height=8.00501, angle=0) S 0.75 1 -0.1
# 2012
# Rectangle(xy=(-0.25, 0), width=0.333333, height=5.65854, angle=0) U -0.25 3.5 -0.1
# Rectangle(xy=(0.75, 0), width=0.333333, height=8.00501, angle=0) S 0.75 4.5 -0.1
